# %% [markdown]
# ### Imports

# %% [markdown]
# ### Training

# %%
# %cd ml-agents
# Out:
# c:\Users\ramsi\OneDrive\Documents\Github Projects\reinforcement-learning\HuggingFace-RLCourse\ml-agents

# %%
# !mlagents-learn "C:\Users\ramsi\OneDrive\Documents\Github Projects\reinforcement-learning\HuggingFace-RLCourse\ml-agents\config\poca\SoccerTwos.yaml" --env="C:\Users\ramsi\OneDrive\Documents\Github Projects\reinforcement-learning\HuggingFace-RLCourse\ml-agents\training-envs-executables\SoccerTwos\SoccerTwos.exe" --run-id="SoccerTwos" --no-graphics --force
# Out:
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 1.1.0.dev0,
#   ml-agents-envs: 1.1.0.dev0,
#   Communicator API: 1.5.0,
#   PyTorch: 2.2.0+cpu
# [INFO] Connected to Unity environment with package version 2.3.0-exp.3 and communication version 1.5.0
# ...

# %% [markdown]
# ### Uploading to HUB

# %%
# !pip install -U "huggingface_hub[cli]"
# Out:
# ...
#      ---------------------------------------- 0.0/67.7 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/67.7 kB ? eta -:--:--
#      ---------------------- --------------- 41.0/67.7 kB 653.6 kB/s eta 0:00:01
#      -------------------------------------- 67.7/67.7 kB 911.7 kB/s eta 0:00:00
# ...

# %%
# !huggingface-cli login --token  --add-to-git-credential
# Out:
# Token is valid (permission: write).
# Your token has been saved in your configured git credential helpers (manager).
# Your token has been saved to C:\Users\ramsi\.cache\huggingface\token
# Login successful

# %%
# !huggingface-cli whoami
# Out:
# ramsi-k

# %%
# !huggingface-cli -h
# Out:
# usage: huggingface-cli <command> [<args>] upload [-h]
#                                                  [--repo-type {model,dataset,space}]
#                                                  [--revision REVISION]
#                                                  [--private]
#                                                  [--include [INCLUDE ...]]
#                                                  [--exclude [EXCLUDE ...]]
#                                                  [--delete [DELETE ...]]
#                                                  [--commit-message COMMIT_MESSAGE]
#                                                  [--commit-description COMMIT_DESCRIPTION]
#                                                  [--create-pr] [--every EVERY]
#                                                  [--token TOKEN] [--quiet]
#                                                  repo_id [local_path]
#                                                  [path_in_repo]
# ...

# %%
# !mlagents-push-to-hf --run-id="SoccerTwos" --local-dir="./results/SoccerTwos" --repo-id="ramsi-k/poca-SoccerTwos" --commit-message="First Push"
# Out:
# [INFO] This function will create a model card and upload your SoccerTwos into HuggingFace Hub. This is a work in progress: If you encounter a bug, please send open an issue
# [INFO] Pushing repo SoccerTwos to the Hugging Face Hub
# [INFO] Your model is pushed to the hub. You can view your model here: https://huggingface.co/ramsi-k/poca-SoccerTwos
# checkpoint.pt:   0%|          | 0.00/28.4M [00:00<?, ?B/s]
#
# events.out.tfevents.1707287610.Ramsi.25680.0:   0%|          | 0.00/2.15M [00:00<?, ?B/s]
#
#
# SoccerTwos-3499416.onnx:   0%|          | 0.00/1.77M [00:00<?, ?B/s]
#
#
#
# Upload 13 LFS files:   0%|          | 0/13 [00:00<?, ?it/s]
#
#
#
#
# SoccerTwos-3999124.onnx:   0%|          | 0.00/1.77M [00:00<?, ?B/s]
#
#
#
#
#
# SoccerTwos-3499416.pt:   0%|          | 0.00/28.4M [00:00<?, ?B/s]
#
#
#
#
# SoccerTwos-3999124.onnx:   1%|          | 16.4k/1.77M [00:00<01:02, 28.2kB/s]
#
# events.out.tfevents.1707287610.Ramsi.25680.0:   1%|          | 16.4k/2.15M [00:00<01:18, 27.1kB/s]
# ...
